# %%
# !git clone https://github.com/weaselchokingonachickenbone69/pest-detection.git
# Out:
# fatal: destination path 'pest-detection' already exists and is not an empty directory.

# %%
# %cd ..
# Out:
# /content/pest-detection

# %%
# !pip install ultralytics
# !pip install numpy
# !pip install matplotlib
# !pip install albumentations
# !pip install tensorflow
# !pip install opencv-python

# %%
from ultralytics import YOLO
import tensorflow
import numpy as np
import matplotlib
import cv2

# %%
model = YOLO('yolov8s.pt')

# %%
results = model.train(
    data='dataset/custom_data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='init_trained_model'
)
# Out:
# Ultralytics 8.3.157 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r model_trained_initial.zip runs/
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/init_trained_model10/ (stored 0%)
#   adding: runs/detect/init_trained_model10/val_batch2_labels.jpg (deflated 5%)
#   adding: runs/detect/init_trained_model10/train_batch8241.jpg (deflated 4%)
#   adding: runs/detect/init_trained_model10/P_curve.png (deflated 12%)
#   adding: runs/detect/init_trained_model10/confusion_matrix.png (deflated 24%)
#   adding: runs/detect/init_trained_model10/val_batch2_pred.jpg (deflated 5%)
#   adding: runs/detect/init_trained_model10/val_batch0_labels.jpg (deflated 4%)
#   adding: runs/detect/init_trained_model10/val_batch1_labels.jpg (deflated 5%)
#   adding: runs/detect/init_trained_model10/R_curve.png (deflated 9%)
#   adding: runs/detect/init_trained_model10/weights/ (stored 0%)
#   adding: runs/detect/init_trained_model10/weights/best.pt (deflated 8%)
#   adding: runs/detect/init_trained_model10/weights/last.pt (deflated 8%)
# ...

# %%
from google.colab import files
files.download("model_trained_initial.zip")
